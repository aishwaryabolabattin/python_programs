# %%
#Write a program to check if number is even or odd.
n=int(input("Enter number:"))
if n%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter number: 74
# Even

# %%
#Write a program to check if number is posi+tive, negative or zeo.
n=int(input("Enter number:"))
if n>0:
    print("Positive")
elif n<0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter number: -86
# Negative

# %%
#Write a program to determine the grade of a student based on their marks.
marks=92
if 90<=marks<=100 :
    print("Grade A")
elif 80<=marks<=90:
    print("Grade B")
elif 70<=marks<=80:
    print("Grade C")
elif 60<=marks<=70:
    print("Grade D")
elif 0<=marks<6=0:
    print("Grade F")
else:
    print("Enter valid marks")
# Out:
# Grade A

# %%
#Write a program to find maximum of three numbers
a=300
b=59
c=299
if a>b and a>c:
    print("a is maximum")
elif b>a and b>c:
    print("b is maximum")
elif c>a and c>b:
    print("b is maximum")
else:
    print("All are same")
# Out:
# a is maximum

# %%
#Write a program to check if a given number is a leap year.
#Rules:
#A year is a leap year if it is divisible by 4 but not divisible by 100 unless it is divisible by 400.
#Input:A single integer for the year.
#Output:"Leap year" or "Not a leap year"
year=2024
if (year%4==0 and year%100!=0) or (year%400==0):
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# Leap year

# %%
#Write a program to check person is eligible to vote.
age=25
if age>=18:
    print("Eligible for vote")
else:
    print("Not eligible for vote")
# Out:
# Eligible for vote

# %%
#Write a program that acts as a simple calculator. It should ask the user for two numbers and an operator (+, -, *, /) and perform the corresponding operation. 
#Input: Two integers and a mathematical operator.
num1=int(input("Enter 1st number:"))
num2=int(input("Enter 2nd number:"))
operator=input("Enter Operator(+,*,/,-):")
if operator=="+":
             print(num1+num2)
elif operator=="*":
            print(num1*num2)
elif operator=="/":
            print(num1/num2)
elif operator=="-":
            print(num1-num2)
else:
            print("Invalid operator")
# Out:
# Enter 1st number: 10
# Enter 2nd number: 67
# Enter Operator(+,*,/,-) +
# 77

# %%
# Write a program to determine the type of triangle based on the  lengths of its three sides. 
#All sides equal: "Equilateral" 
#Two sides equal: "Isosceles" 
#All sides different: "Scalene"

a=int(input("Enter first side:"))
b=int(input("Enter second side:"))
c=int(input("Enter third side:"))
if a==b==c:
    print("Equailateral")
elif a==b or b==c or a==c:
    print("Isosceles")
else:
    print("Scalene")
# Out:
# Enter first side: 10
# Enter second side: 74
# Enter third side: 58
# Scalene

# %%
#A student will not be 
#
to attend the exam if his/her attendance
#isless than 75%. Take following input from user – 
#Number of classes held  
#Number of classes attended  
#And print on the percentage of class attended Is student is allowed 
#to attend the exam or not.
classes_held=int(input("Enter the classes held:"))
classes_attended=int(input("Enter the classes attended:"))
attendance_percentage=classes_attended/classes_held*100
if attendance_percentage>75:
    print(attendance_percentage)
    print("Allow to attend the exam")
else:
    print("Not attend the exam")
# Out:
# Enter the classes held: 25
# Enter the classes attended: 75
# 300.0
# Allow to attend the exam

# %%
#A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years. Ask user for their salary and year of service and print the net bonus amount.
salary=int(input("Enter salary:"))
year_service=int(input("Enter year of service:"))
if year_service>5:
    bonus=salary*5/100
    print(bonus)
    net_salary=salary+bonus
    print(net_salary)
else:
    print("Bhai aur ghisna padega..")
# Out:
# Enter salary: 50000
# Enter year of service: 10
# 2500.0
# 52500.0
