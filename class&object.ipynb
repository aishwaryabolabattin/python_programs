# %%
class Dog:
    specifie:"Canine"   #class attribute
    def __init__(self,name,age):
        self.name=name
        self.age=age        #instance attribute

dog1=Dog("Tuffy",5)
print(dog1.name)
print(dog1.age)
# Out:
# Tuffy
# 5

# %%
#Write a Python program to create a class Person with the attributes name and age. Instantiate an object of the class and print the attributes.
class Person:
    
    def __init__(self,name,age):
        self.name=name
        self.age=age
person1=Person("Aishu",22)
print(person1.name)
print(person1.age)
# Out:
# Aishu
# 22

# %%
#Write a Python class Car with attributes make and model. Add a method display_info() that prints the car’s make and model. Create an instance and call this method.
class car:
    def __init__(self,make,model):
        self.make=make
        self.model=model
    def display_info(self):
        print("Make is:",self.make)
        print("Model is:",self.model)

car1=car("Toyota","Corolla")
car1.display_info()
# Out:
# Make is: Toyota
# Model is: Corolla

# %%
#Write a Python program that defines a class Person with a constructor that initializes role and salary. Instantiate an object and print the values of role and salary.
class person:
    def __init__(self,role,salary):
        self.role=role
        self.salary=salary
person1=person("Software Engineer",50000)
print(person1.role)
print(person1.salary)
# Out:
# Software Engineer
# 50000

# %%
#Write a Python class Book with a default constructor. If no arguments are provided, set title and author to default values ("Unknown" and "Unknown").
class book:
    def __init__(self,title="Unknown",author="Unknown"):
        self.title=title
        self.author=author
book1=book("Shyamachi Aai","Sane Guruji")
print(book1.title)
print(book1.author)
# Out:
# Shyamachi Aai
# Sane Guruji

# %%
#Write a Python program that creates a Rectangle class with a constructor that takes width and height as arguments. The constructor should initialize these attributes and calculate the area.
class Rectangle:
    def __init__(self,width,height):
        self.width=width
        self.height=height
        self.area=self.width*self.height
rectangle1=Rectangle(5,8)
print(rectangle1.width)
print(rectangle1.height)
print(rectangle1.area)
# Out:
# 5
# 8
# 40

# %%
#Define a simple Person class with a destructor _del_(). Print a message when an object of the Person class is deleted.
class person:
    def __init__(self,name):
        self.name=name
        print("name is created")
    def __del__(self):
        print("name is deleted")
person1=person("Sonali")
del person1
# Out:
# name is created
# name is deleted

# %%
#Write a Python program that defines a Car class with two constructors: one for setting make and model, and another for setting
class car:
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
    def display_info(self):
        print("make is:",self.make)
        print("model is:",self.model)
        print("Year is:",self.year)

car1=car("Toyota","Corolla",2025)
car1.display_info()

car2=car("Honda","Civic",2026)
car2.display_info()
# Out:
# make is: Toyota
# model is: Corolla
# Year is: 2025
# make is: Honda
# model is: Civic
# Year is: 2026

# %%
#Write a Python program that defines a Person class with a constructor that takes age as an argument. If the age is less than 18, assign the person to a "minor" group; otherwise, assign them to an "adult" group.
class person:
    def __init__(self,age):
        self.age=age

        if age<18:
            print("Minor")
        else:
            print("Adult")
person1=person(20)
# Out:
# Adult
